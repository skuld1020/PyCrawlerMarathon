# %% [markdown]
# ### 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）<br>
# 以下先以ptt八卦板為例

# %%
#未加session 或 cookie的情況下

import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
res = requests.get(url)

soup = BeautifulSoup(res.text,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div class="bbs-screen bbs-content">
# <div class="over18-notice">
# <p>本網站已依網站內容分級規定處理</p>
# <p>警告︰您即將進入之看板內容需滿十八歲方可瀏覽。</p>
# <p>若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。</p>
# </div>
# </div>
# <div class="bbs-screen bbs-content center clear">
# <form action="/ask/over18" method="post">
# <input name="from" type="hidden" value="/bbs/Gossiping/index.html"/>
# <div class="over18-button-container">
# <button class="btn-big" name="yes" type="submit" value="yes">我同意，我已年滿十八歲<br/><small>進入</small></button>
# </div>
# <div class="over18-button-container">
# <button class="btn-big" name="no" type="submit" value="no">未滿十八歲或不同意本條款<br/><small>離開</small></button>
# </div>
# </form>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
# </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup

#利用session
rs = requests.session()
payload = {'from':'/bbs/Gossiping/index.html',
          'yes':'yes'}

#在requests做请求的时候，为了避免ssl认证，可以放入參數verify=False(但是日誌會報warning，不影響結果)
#先送請求模擬登入(確認滿18歲)
#為了將報錯訊息去掉，多加requests.packages.urllib3.disable_warnings()即可
requests.packages.urllib3.disable_warnings()
res = rs.post('https://www.ptt.cc/ask/over18',verify=False,data = payload)

#再次發送請求網頁資訊
url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
res = rs.get(url)

soup = BeautifulSoup(res.text,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="main-container">
# <div id="action-bar-container">
# <div class="action-bar">
# <div class="btn-group btn-group-dir">
# <a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# <a class="btn" href="/man/Gossiping/index.html">精華區</a>
# </div>
# <div class="btn-group btn-group-paging">
# <a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# <a class="btn wide" href="/bbs/Gossiping/index39490.html">‹ 上頁</a>
# <a class="btn wide disabled">下頁 ›</a>
# <a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# </div>
# </div>
# </div>
# <div class="r-list-container action-bar-margin bbs-screen">
# <div class="search-bar">
# <form action="search" id="search-bar" type="get">
# <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
# </form>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">4</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598031028.A.F2F.html">[問卦] 吸毒之後殺人無罪</a>
# </div>
# <div class="meta">
# <div class="author">whiteadam</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E5%90%B8%E6%AF%92%E4%B9%8B%E5%BE%8C%E6%AE%BA%E4%BA%BA%E7%84%A1%E7%BD%AA">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Awhiteadam">搜尋看板內 whiteadam 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f0">X2</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598031076.A.154.html">Re: [新聞] 獨家》國民黨考慮藍14縣市聯合入境普篩</a>
# </div>
# <div class="meta">
# <div class="author">sanny0912</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E7%8D%A8%E5%AE%B6%E3%80%8B%E5%9C%8B%E6%B0%91%E9%BB%A8%E8%80%83%E6%85%AE%E8%97%8D14%E7%B8%A3%E5%B8%82%E8%81%AF%E5%90%88%E5%85%A5%E5%A2%83%E6%99%AE%E7%AF%A9">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Asanny0912">搜尋看板內 sanny0912 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598031284.A.D5E.html">Re: [新聞] 支持港警施暴 《花木蘭》在韓遭抵制</a>
# </div>
# <div class="meta">
# <div class="author">a945438</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E6%94%AF%E6%8C%81%E6%B8%AF%E8%AD%A6%E6%96%BD%E6%9A%B4+%E3%80%8A%E8%8A%B1%E6%9C%A8%E8%98%AD%E3%80%8B%E5%9C%A8%E9%9F%93%E9%81%AD%E6%8A%B5%E5%88%B6">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aa945438">搜尋看板內 a945438 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">2</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598031312.A.73D.html">[問卦] 台南的房租484比台中還貴阿？</a>
# </div>
# <div class="meta">
# <div class="author">wuyiulin</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E5%8F%B0%E5%8D%97%E7%9A%84%E6%88%BF%E7%A7%9F484%E6%AF%94%E5%8F%B0%E4%B8%AD%E9%82%84%E8%B2%B4%E9%98%BF%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Awuyiulin">搜尋看板內 wuyiulin 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">5</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598031382.A.577.html">[問卦] Potplayer 三天兩頭更新是在更三小</a>
# </div>
# <div class="meta">
# <div class="author">Warheart</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+Potplayer+%E4%B8%89%E5%A4%A9%E5%85%A9%E9%A0%AD%E6%9B%B4%E6%96%B0%E6%98%AF%E5%9C%A8%E6%9B%B4%E4%B8%89%E5%B0%8F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3AWarheart">搜尋看板內 Warheart 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598031394.A.7E9.html">[問卦] 有沒有用心製作音樂卻無法爆紅的人</a>
# </div>
# <div class="meta">
# <div class="author">aki1023</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E6%9C%89%E6%B2%92%E6%9C%89%E7%94%A8%E5%BF%83%E8%A3%BD%E4%BD%9C%E9%9F%B3%E6%A8%82%E5%8D%BB%E7%84%A1%E6%B3%95%E7%88%86%E7%B4%85%E7%9A%84%E4%BA%BA">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aaki1023">搜尋看板內 aki1023 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">2</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598031457.A.104.html">[問卦] 小時候當廖耙仔的長大都在幹嘛</a>
# </div>
# <div class="meta">
# <div class="author">killerchi</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E5%B0%8F%E6%99%82%E5%80%99%E7%95%B6%E5%BB%96%E8%80%99%E4%BB%94%E7%9A%84%E9%95%B7%E5%A4%A7%E9%83%BD%E5%9C%A8%E5%B9%B9%E5%98%9B">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Akillerchi">搜尋看板內 killerchi 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-list-sep"></div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1595260807.A.E89.html">[公告] 八卦板板規(2020.07.21)</a>
# </div>
# <div class="meta">
# <div class="author">seabox</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E5%85%AB%E5%8D%A6%E6%9D%BF%E6%9D%BF%E8%A6%8F%282020.07.21%29">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aseabox">搜尋看板內 seabox 的文章</a></div>
# </div>
# </div>
# <div class="date"> 7/21</div>
# <div class="mark">!</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1597395423.A.0FC.html">[協尋] 8/12 屏東 萬順路與崙中路口 行車紀錄器</a>
# </div>
# <div class="meta">
# <div class="author">water112</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D+8%2F12+%E5%B1%8F%E6%9D%B1+%E8%90%AC%E9%A0%86%E8%B7%AF%E8%88%87%E5%B4%99%E4%B8%AD%E8%B7%AF%E5%8F%A3+%E8%A1%8C%E8%BB%8A%E7%B4%80%E9%8C%84%E5%99%A8">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Awater112">搜尋看板內 water112 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/14</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1597380236.A.3AB.html">[協尋] 8/12  12:10~12:40行經花東鹽寮北上影像</a>
# </div>
# <div class="meta">
# <div class="author">monarch0301</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D+8%2F12++12%3A10~12%3A40%E8%A1%8C%E7%B6%93%E8%8A%B1%E6%9D%B1%E9%B9%BD%E5%AF%AE%E5%8C%97%E4%B8%8A%E5%BD%B1%E5%83%8F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Amonarch0301">搜尋看板內 monarch0301 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/14</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">68</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1597762934.A.F53.html">Fw: [徵求]行車紀錄8/17台南新市區永就里am7-8</a>
# </div>
# <div class="meta">
# <div class="author">ROCKMAX</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%BE%B5%E6%B1%82%5D%E8%A1%8C%E8%BB%8A%E7%B4%80%E9%8C%848%2F17%E5%8F%B0%E5%8D%97%E6%96%B0%E5%B8%82%E5%8D%80%E6%B0%B8%E5%B0%B1%E9%87%8Cam7-8">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3AROCKMAX">搜尋看板內 ROCKMAX 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/18</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598004550.A.04B.html">[協尋] 8/17新北五股垃圾山命案行車記錄器</a>
# </div>
# <div class="meta">
# <div class="author">kamiko0901</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D+8%2F17%E6%96%B0%E5%8C%97%E4%BA%94%E8%82%A1%E5%9E%83%E5%9C%BE%E5%B1%B1%E5%91%BD%E6%A1%88%E8%A1%8C%E8%BB%8A%E8%A8%98%E9%8C%84%E5%99%A8">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Akamiko0901">搜尋看板內 kamiko0901 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/21</div>
# <div class="mark"></div>
# </div>
# </div>
# </div>
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
# </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
#直接加入cookies
cookies = {'over18':'1'}
res = requests.get(url,cookies=cookies)

soup = BeautifulSoup(res.text,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="main-container">
# <div id="action-bar-container">
# <div class="action-bar">
# <div class="btn-group btn-group-dir">
# <a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# <a class="btn" href="/man/Gossiping/index.html">精華區</a>
# </div>
# <div class="btn-group btn-group-paging">
# <a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# <a class="btn wide" href="/bbs/Gossiping/index39490.html">‹ 上頁</a>
# <a class="btn wide disabled">下頁 ›</a>
# <a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# </div>
# </div>
# </div>
# <div class="r-list-container action-bar-margin bbs-screen">
# <div class="search-bar">
# <form action="search" id="search-bar" type="get">
# <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
# </form>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">5</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598031028.A.F2F.html">[問卦] 吸毒之後殺人無罪</a>
# </div>
# <div class="meta">
# <div class="author">whiteadam</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E5%90%B8%E6%AF%92%E4%B9%8B%E5%BE%8C%E6%AE%BA%E4%BA%BA%E7%84%A1%E7%BD%AA">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Awhiteadam">搜尋看板內 whiteadam 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f0">X3</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598031076.A.154.html">Re: [新聞] 獨家》國民黨考慮藍14縣市聯合入境普篩</a>
# </div>
# <div class="meta">
# <div class="author">sanny0912</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E7%8D%A8%E5%AE%B6%E3%80%8B%E5%9C%8B%E6%B0%91%E9%BB%A8%E8%80%83%E6%85%AE%E8%97%8D14%E7%B8%A3%E5%B8%82%E8%81%AF%E5%90%88%E5%85%A5%E5%A2%83%E6%99%AE%E7%AF%A9">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Asanny0912">搜尋看板內 sanny0912 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598031284.A.D5E.html">Re: [新聞] 支持港警施暴 《花木蘭》在韓遭抵制</a>
# </div>
# <div class="meta">
# <div class="author">a945438</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E6%94%AF%E6%8C%81%E6%B8%AF%E8%AD%A6%E6%96%BD%E6%9A%B4+%E3%80%8A%E8%8A%B1%E6%9C%A8%E8%98%AD%E3%80%8B%E5%9C%A8%E9%9F%93%E9%81%AD%E6%8A%B5%E5%88%B6">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aa945438">搜尋看板內 a945438 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">4</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598031312.A.73D.html">[問卦] 台南的房租484比台中還貴阿？</a>
# </div>
# <div class="meta">
# <div class="author">wuyiulin</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E5%8F%B0%E5%8D%97%E7%9A%84%E6%88%BF%E7%A7%9F484%E6%AF%94%E5%8F%B0%E4%B8%AD%E9%82%84%E8%B2%B4%E9%98%BF%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Awuyiulin">搜尋看板內 wuyiulin 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">6</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598031382.A.577.html">[問卦] Potplayer 三天兩頭更新是在更三小</a>
# </div>
# <div class="meta">
# <div class="author">Warheart</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+Potplayer+%E4%B8%89%E5%A4%A9%E5%85%A9%E9%A0%AD%E6%9B%B4%E6%96%B0%E6%98%AF%E5%9C%A8%E6%9B%B4%E4%B8%89%E5%B0%8F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3AWarheart">搜尋看板內 Warheart 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598031394.A.7E9.html">[問卦] 有沒有用心製作音樂卻無法爆紅的人</a>
# </div>
# <div class="meta">
# <div class="author">aki1023</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E6%9C%89%E6%B2%92%E6%9C%89%E7%94%A8%E5%BF%83%E8%A3%BD%E4%BD%9C%E9%9F%B3%E6%A8%82%E5%8D%BB%E7%84%A1%E6%B3%95%E7%88%86%E7%B4%85%E7%9A%84%E4%BA%BA">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aaki1023">搜尋看板內 aki1023 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">4</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598031457.A.104.html">[問卦] 小時候當廖耙仔的長大都在幹嘛</a>
# </div>
# <div class="meta">
# <div class="author">killerchi</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E5%B0%8F%E6%99%82%E5%80%99%E7%95%B6%E5%BB%96%E8%80%99%E4%BB%94%E7%9A%84%E9%95%B7%E5%A4%A7%E9%83%BD%E5%9C%A8%E5%B9%B9%E5%98%9B">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Akillerchi">搜尋看板內 killerchi 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598031612.A.94A.html">Re: [新聞] 獨家》國民黨考慮藍14縣市聯合入境普篩</a>
# </div>
# <div class="meta">
# <div class="author">Scion</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E7%8D%A8%E5%AE%B6%E3%80%8B%E5%9C%8B%E6%B0%91%E9%BB%A8%E8%80%83%E6%85%AE%E8%97%8D14%E7%B8%A3%E5%B8%82%E8%81%AF%E5%90%88%E5%85%A5%E5%A2%83%E6%99%AE%E7%AF%A9">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3AScion">搜尋看板內 Scion 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">1</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598031646.A.48C.html">[問卦] 日女怎麼沒有越想越不對勁</a>
# </div>
# <div class="meta">
# <div class="author">herex</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E6%97%A5%E5%A5%B3%E6%80%8E%E9%BA%BC%E6%B2%92%E6%9C%89%E8%B6%8A%E6%83%B3%E8%B6%8A%E4%B8%8D%E5%B0%8D%E5%8B%81">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aherex">搜尋看板內 herex 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598031666.A.E5B.html">[問卦] 有貓貓四不四要給推</a>
# </div>
# <div class="meta">
# <div class="author">takashi01</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D+%E6%9C%89%E8%B2%93%E8%B2%93%E5%9B%9B%E4%B8%8D%E5%9B%9B%E8%A6%81%E7%B5%A6%E6%8E%A8">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Atakashi01">搜尋看板內 takashi01 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/22</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-list-sep"></div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1595260807.A.E89.html">[公告] 八卦板板規(2020.07.21)</a>
# </div>
# <div class="meta">
# <div class="author">seabox</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E5%85%AB%E5%8D%A6%E6%9D%BF%E6%9D%BF%E8%A6%8F%282020.07.21%29">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Aseabox">搜尋看板內 seabox 的文章</a></div>
# </div>
# </div>
# <div class="date"> 7/21</div>
# <div class="mark">!</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1597395423.A.0FC.html">[協尋] 8/12 屏東 萬順路與崙中路口 行車紀錄器</a>
# </div>
# <div class="meta">
# <div class="author">water112</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D+8%2F12+%E5%B1%8F%E6%9D%B1+%E8%90%AC%E9%A0%86%E8%B7%AF%E8%88%87%E5%B4%99%E4%B8%AD%E8%B7%AF%E5%8F%A3+%E8%A1%8C%E8%BB%8A%E7%B4%80%E9%8C%84%E5%99%A8">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Awater112">搜尋看板內 water112 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/14</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1597380236.A.3AB.html">[協尋] 8/12  12:10~12:40行經花東鹽寮北上影像</a>
# </div>
# <div class="meta">
# <div class="author">monarch0301</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D+8%2F12++12%3A10~12%3A40%E8%A1%8C%E7%B6%93%E8%8A%B1%E6%9D%B1%E9%B9%BD%E5%AF%AE%E5%8C%97%E4%B8%8A%E5%BD%B1%E5%83%8F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Amonarch0301">搜尋看板內 monarch0301 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/14</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">68</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1597762934.A.F53.html">Fw: [徵求]行車紀錄8/17台南新市區永就里am7-8</a>
# </div>
# <div class="meta">
# <div class="author">ROCKMAX</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%BE%B5%E6%B1%82%5D%E8%A1%8C%E8%BB%8A%E7%B4%80%E9%8C%848%2F17%E5%8F%B0%E5%8D%97%E6%96%B0%E5%B8%82%E5%8D%80%E6%B0%B8%E5%B0%B1%E9%87%8Cam7-8">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3AROCKMAX">搜尋看板內 ROCKMAX 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/18</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/Gossiping/M.1598004550.A.04B.html">[協尋] 8/17新北五股垃圾山命案行車記錄器</a>
# </div>
# <div class="meta">
# <div class="author">kamiko0901</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D+8%2F17%E6%96%B0%E5%8C%97%E4%BA%94%E8%82%A1%E5%9E%83%E5%9C%BE%E5%B1%B1%E5%91%BD%E6%A1%88%E8%A1%8C%E8%BB%8A%E8%A8%98%E9%8C%84%E5%99%A8">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Gossiping/search?q=author%3Akamiko0901">搜尋看板內 kamiko0901 的文章</a></div>
# </div>
# </div>
# <div class="date"> 8/21</div>
# <div class="mark"></div>
# </div>
# </div>
# </div>
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
# </body>
# </html>

# %% [markdown]
# ### 以https://github.com/new為例

# %%
import requests
from bs4 import BeautifulSoup
url ='https://github.com/new'
res = requests.get(url)

soup = BeautifulSoup(res.text,'html.parser')
soup

#因為沒有登入，所以被導到登入畫面
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-8c550109d58e0353afdf1a37a05301c2.css" integrity="sha512-jFUBCdWOA1Ov3xo3oFMBwsdP4Up2K1bRnP4QYI5WqvpaIYxWVek89k2M0oyTbNhYMViGtxJB3Vdwcw8ln8hGQw==" media="all" rel="stylesheet">
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/site-7ea9d9b5acaa80b0a67107f15e9e4e1f.css" integrity="sha512-fqnZtayqgLCmcQfxXp5OH4orKvv16fP0zCU6Ns+NuAULztoXdSMDcdECjHWSFA018nYJNqWh1OXhgZ9W8EMMQw==" media="all" rel="stylesheet">
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/github-36f60e1fc11f3e85242ffa676dd886fe.css" integrity="sha512-NvYOH8EfPoUkL/pnbdiG/jpmBFbDYLFq3u7YDcnIoDy8RFMMCj2yxgbWKqSBWRpok0zDEdSYxnLQ0utEcw3BrA==" media="all" rel="stylesheet">
# <meta content="width=device-width" name="viewport"/>
# <title>Sign in to GitHub · GitHub</title>
# <meta content="GitHub is where people build software. More than 50 million people use GitHub to discover, fork, and contribute to over 100 million projects." name="description"/>
# <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
# <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
# <meta content="1401488693436528" property="fb:app_id"/>
# <meta content="app-id=1477376905" name="apple-itunes-app"/>
# <meta content="https://github.com" property="og:url"/>
# <meta content="GitHub" property="og:site_name"/>
# <meta content="Build software better, together" property="og:title"/>
# <meta content="GitHub is where people build software. More than 50 million people use GitHub to discover, fork, and contribute to over 100 million projects." property="og:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="1200" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-mark.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-octocat.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="github" property="twitter:site"/>
# <meta content="13334762" property="twitter:site:id"/>
# <meta content="github" property="twitter:creator"/>
# <meta content="13334762" property="twitter:creator:id"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="GitHub" property="twitter:title"/>
# <meta content="GitHub is where people build software. More than 50 million people use GitHub to discover, fork, and contribute to over 100 million projects." property="twitter:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="twitter:image:src"/>
# <meta content="1200" property="twitter:image:width"/>
# <meta content="1200" property="twitter:image:height"/>
# <link href="https://github.githubassets.com/" rel="assets"/>
# <meta content="D799:23CA:66630:AD425:5F400970" data-pjax-transient="true" name="request-id"><meta content="01fd604e8c5cdce86c1751900ff0443d5a8ad8cc" data-pjax-transient="true" name="html-safe-nonce"><meta content="eyJyZWZlcnJlciI6bnVsbCwicmVxdWVzdF9pZCI6IkQ3OTk6MjNDQTo2NjYzMDpBRDQyNTo1RjQwMDk3MCIsInZpc2l0b3JfaWQiOiI2MzI0OTU5ODc3NTM3OTkxMDI0IiwicmVnaW9uX2VkZ2UiOiJpYWQiLCJyZWdpb25fcmVuZGVyIjoiaWFkIn0=" data-pjax-transient="true" name="visitor-payload"><meta content="28aa6f8e8d26a13c588996bcd6f681f8dc35434db5c29e1f03ca70dbadf171ca" data-pjax-transient="true" name="visitor-hmac">
# <meta content="" data-pjax-transient="true" name="github-keyboard-shortcuts">
# <meta data-pjax-transient="" name="selected-link" value="/login"/>
# <meta content="c1kuD-K2HIVF635lypcsWPoD4kilo5-jA_wBFyT4uMY" name="google-site-verification"/>
# <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification"/>
# <meta content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA" name="google-site-verification"/>
# <meta content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc" name="google-site-verification"/>
# <meta content="collector.githubapp.com" name="octolytics-host"><meta content="github" name="octolytics-app-id"><meta content="https://collector.githubapp.com/github-external/browser_event" name="octolytics-event-url"><meta class="js-octo-ga-id" content="" name="octolytics-dimension-ga_id">
# <meta content="true" data-pjax-transient="true" name="analytics-location-query-strip">
# <meta content="UA-3769691-2" name="google-analytics"/>
# <meta class="js-ga-set" content="Responsive" data-pjax-transient="" name="dimension10"/>
# <meta class="js-ga-set" content="Logged Out" name="dimension1"/>
# <meta content="github.com" name="hostname"/>
# <meta content="" name="user-login"/>
# <meta content="github.com" name="expected-hostname"/>
# <meta content="MARKETPLACE_PENDING_INSTALLATIONS" name="enabled-features"/>
# <meta content="269f8c88eed84e4178a5f9feca9bdb9c" http-equiv="x-pjax-version"/>
# <link data-pjax-transient="" href="https://github.com/login" rel="canonical"/>
# <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
# <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
# <link color="#000000" href="https://github.githubassets.com/pinned-octocat.svg" rel="mask-icon"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.png" rel="alternate icon" type="image/png"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="#1e2327" name="theme-color"/>
# <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
# </meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></link></link></link></head>
# <body class="logged-out env-production page-responsive session-authentication">
# <div class="position-relative js-header-wrapper">
# <a class="px-2 py-4 bg-blue text-white show-on-focus js-skip-to-content" href="#start-of-content">Skip to content</a>
# <span class="progress-pjax-loader width-full js-pjax-loader-bar Progress position-fixed">
# <span class="Progress-item progress-pjax-loader-bar" style="background-color: #79b8ff;width: 0%;"></span>
# </span>
# <div class="unsupported-browser" hidden="" id="unsupported-browser">
# <div class="container-lg p-responsive clearfix d-flex flex-items-center py-2">
# <svg aria-hidden="true" class="octicon octicon-alert mr-2 color-gray-7 hide-sm" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path></svg>
# <div class="d-flex flex-auto flex-column flex-md-row">
# <div class="flex-auto min-width-0 mr-2" style="padding-top:1px">
# <span>GitHub no longer supports this web browser.</span>
# <a href="https://docs.github.com/articles/supported-browsers">
#           Learn more about the browsers we support.
#         </a>
# </div>
# </div>
# </div>
# </div>
# <div class="header header-logged-out width-full pt-5 pb-4" role="banner">
# <div class="container clearfix width-full text-center">
# <a aria-label="Homepage" class="header-logo" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github" height="48" version="1.1" viewbox="0 0 16 16" width="48"><path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path></svg>
# </a>
# </div>
# </div>
# </div>
# <div class="show-on-focus" id="start-of-content"></div>
# <include-fragment class="js-notification-shelf-include-fragment" data-base-src="https://github.com/notifications/beta/shelf"></include-fragment>
# <div class="application-main" data-commit-hovercards-enabled="" data-discussion-hovercards-enabled="" data-issue-and-pr-hovercards-enabled="">
# <main data-pjax-container="" id="js-pjax-container">
# <div class="auth-form px-3" id="login">
# <!-- '"` --><!-- </textarea></xmp> --></div></main></div></body></html><form accept-charset="UTF-8" action="/session" method="post"><input name="authenticity_token" type="hidden" value="nL3hUAylUwiNWudmo1UyLmJMF9g19LU3kk83EkXdxCvBZiT+F21dCXxEtArAoeBZz95RnxA/MBuMxqd0O4UIiw=="/> <input class="js-octo-ga-id-input" name="ga_id" type="hidden"/>
# <div class="auth-form-header p-0">
# <h1>Sign in to GitHub</h1>
# </div>
# <div id="js-flash-container">
# <template class="js-flash-template">
# <div class="flash flash-full {{ className }}">
# <div class="container-lg px-2">
# <button aria-label="Dismiss this message" class="flash-close js-flash-close" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path></svg>
# </button>
# <div>{{ message }}</div>
# </div>
# </div>
# </template>
# </div>
# <div class="flash js-transform-notice" hidden="">
# <button aria-label="Dismiss this message" class="flash-close js-flash-close" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path></svg>
# </button>
# </div>
# <div class="auth-form-body mt-3">
# <label for="login_field">
#           Username or email address
#         </label>
# <input autocapitalize="off" autocomplete="username" autocorrect="off" autofocus="autofocus" class="form-control input-block" id="login_field" name="login" tabindex="1" type="text">
# <label for="password">
#           Password <a class="label-link" href="/password_reset">Forgot password?</a>
# </label>
# <input autocomplete="current-password" class="form-control form-control input-block" id="password" name="password" tabindex="2" type="password"/>
# <input class="js-webauthn-support" name="webauthn-support" type="hidden" value="unknown"/>
# <input class="js-webauthn-iuvpaa-support" name="webauthn-iuvpaa-support" type="hidden" value="unknown"/>
# <input class="form-control" id="return_to" name="return_to" type="hidden" value="https://github.com/new">
# <input class="form-control" hidden="hidden" name="required_field_afc5" type="text"><input class="form-control" name="timestamp" type="hidden" value="1598032240443"/><input class="form-control" name="timestamp_secret" type="hidden" value="8c539be73338ecac1aa21085e47950ea4bb3a10aaa1884c94f09ac2ebd0cd384"/>
# <input class="btn btn-primary btn-block" data-disable-with="Signing in…" name="commit" tabindex="3" type="submit" value="Sign in"/>
# </input></input></input></div>
# </form>
# <p class="create-account-callout mt-3">
#         New to GitHub?
#         <a data-ga-click="Sign in, switch to sign up" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"sign in switch to sign up","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/login?return_to=https%3A%2F%2Fgithub.com%2Fnew","user_id":null}}' data-hydro-click-hmac="0587bd112e9c8e12a5a0e78065bc3ca094ae87582ecfbcc87c45d161429aeaa3" href="/join?return_to=https%3A%2F%2Fgithub.com%2Fnew&amp;source=login">Create an account</a>.
#       </p>
#
#
#
# <div class="footer container-lg p-responsive py-6 mt-6 f6" role="contentinfo">
# <ul class="list-style-none d-flex flex-justify-center">
# <li class="mr-3"><a data-ga-click="Footer, go to terms, text:terms" href="/site/terms">Terms</a></li>
# <li class="mr-3"><a data-ga-click="Footer, go to privacy, text:privacy" href="/site/privacy">Privacy</a></li>
# <li class="mr-3"><a data-ga-click="Footer, go to security, text:security" href="https://docs.github.com/articles/github-security/">Security</a></li>
# <li><a class="link-gray" data-ga-click="Footer, go to contact, text:contact" href="https://github.com/contact">Contact GitHub</a></li>
# </ul>
# </div>
# <div class="ajax-error-message flash flash-error" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path></svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path></svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <script async="async" crossorigin="anonymous" data-src="https://github.githubassets.com/assets/compat-bootstrap-6e7ff7ac.js" id="js-conditional-compat" integrity="sha512-bn/3rKJzBl2H64K38R8KaVcT26vKK7BJQC59lwYc+9fjlHzmy0fwh+hzBtsgTdhIi13dxjzNKWhdSN8WTM9qUw==" type="application/javascript"></script>
# <script crossorigin="anonymous" integrity="sha512-CxjaMepCmi+z0LTeztU2S8qGD25LyHD6j9t0RSPevy63trFWJVwUM6ipAVLgtpMBBgZ53wq8JPkSeQ6ruaZL2w==" src="https://github.githubassets.com/assets/environment-bootstrap-0b18da31.js" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" integrity="sha512-IzHxwH/3JQZfzvuwDWsyetKq8ns1nrrFWFyewxnSV8Vtb8hHN+l+BSPfFgYCC4eiNfzk1ZhKQl5WSv5k8dhJcg==" src="https://github.githubassets.com/assets/vendor-2331f1c0.js" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" integrity="sha512-SV6+q8uXFyBUWqEkDIVsYjJQXbWBMiPgHnfwvyqDM9HLivaP1y6WTLwXq4KhA9FMMNe0goW7KIidp3oba/Xc8Q==" src="https://github.githubassets.com/assets/frameworks-495ebeab.js" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" integrity="sha512-B3oIIhkdTIpj/Ksw5Of4I2hcifoHv8UNyFdLdVsmV55JQ2KWWlhWcenavdyhx/M5LzMXqp4jJaxiFnRUguYhmA==" src="https://github.githubassets.com/assets/behaviors-bootstrap-077a0822.js" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" data-module-id="./Sortable.js" data-src="https://github.githubassets.com/assets/Sortable-4e398351.js" integrity="sha512-TjmDUfspgN28WRWfc01tOL0BFS8pI/TAi8TQ665TcA3jG1C3QgfFu0YKa32Z03rlEL8dukbsy+amwBzgGyjESQ==" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" data-module-id="./contributions-spider-graph.js" data-src="https://github.githubassets.com/assets/contributions-spider-graph-f2149c97.js" integrity="sha512-8hScl0DkWwAjCqAQA50kQOn2QTYfPcKEyJjkKYtjGB88r9GB/6kmBBsneJPgwhW3yewwt64ABgsQGpQSLX8zpg==" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" data-module-id="./drag-drop.js" data-src="https://github.githubassets.com/assets/drag-drop-a7f9f6bb.js" integrity="sha512-p/n2uyeIUJ0ZzcJpzN2xH/pWSc/7ma1KYdOzhZf99ejmsdlsUAl0cXnptZfWJM7Vd8dhQGfhqfn4xJux5cgaVg==" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" data-module-id="./image-crop-element-loader.js" data-src="https://github.githubassets.com/assets/image-crop-element-loader-88bb82db.js" integrity="sha512-iLuC2weaJqL9mYAud2WDWjhd8cJe8dXVxw2KhCH2Rnj6WJvTzlZRmvTtL09wNWX6nRze/TDaQ7gq7BFLchaDYg==" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" data-module-id="./jump-to.js" data-src="https://github.githubassets.com/assets/jump-to-69a58607.js" integrity="sha512-aaWGB9J9tiPrApA/TphHG7EYGpV9Y81ohGUYxy8xm9PAYTFBFWtI36T8g4B8HTJCN7Azzf+WX7x3+rfYb4Nrcg==" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" data-module-id="./profile-pins-element.js" data-src="https://github.githubassets.com/assets/profile-pins-element-1f359478.js" integrity="sha512-HzWUeLy0p20M4Lc3+EerTwy/VaH3vMuKLvhFJr0PsJfKXnsD9oy5SfashhxStUirglhYZUB4fLYQRM1uzrFyNg==" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" data-module-id="./randomColor.js" data-src="https://github.githubassets.com/assets/randomColor-a840affe.js" integrity="sha512-qECv/jhsvLFN77eGNu0cjMR2+zvAlLyhQVTnmayJc5OLZoxMLjQZxZW1hK/dhcYro6Wec/aiF21HYf2N5OilYQ==" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" data-module-id="./tweetsodium.js" data-src="https://github.githubassets.com/assets/tweetsodium-987aac13.js" integrity="sha512-mHqsE5aQq7fAmmLd0epHBJK8rn8DOVnjW2YQOT8wvsN1oLrypw0cDFmwXPDwbMghHyo4kKiOtVJ/kEsEzwwibw==" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" data-module-id="./user-status-submit.js" data-src="https://github.githubassets.com/assets/user-status-submit-98d9c443.js" integrity="sha512-mNnEQyRrGnUV16QPZbBn02HR4XiKAn0sGYkalkzX4MmAmnmSrkrbIrLCX7/ry3J93s8ehsIoPn6Ua3AMorNgMA==" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" integrity="sha512-SOPCtlkpsYIiiv0utjiUwpRmbrF6CURJhp85R9g+UT1j9mrE1Da0NsaRt7hkBMOp2eAFYuZRXmhN//ubNdehtg==" src="https://github.githubassets.com/assets/unsupported-bootstrap-48e3c2b6.js" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" integrity="sha512-ALIi035+4c+/6JkVB/0I7/go/s/grxrpoCCX4918OTZAh1kCqxsPzRjgcfW1H9iLs68yLAnRN3uA72yNQA0T/w==" src="https://github.githubassets.com/assets/github-bootstrap-00b222d3.js" type="application/javascript"></script>
# <div class="js-stale-session-flash flash flash-warn flash-banner" hidden="">
# <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path></svg>
# <span class="js-stale-session-flash-signed-in" hidden="">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>
# <span class="js-stale-session-flash-signed-out" hidden="">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>
# </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default text-gray-dark hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path></svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box box-shadow-large" style="width:360px;">
# </div>
# </div>

# %%
import requests
from bs4 import BeautifulSoup
url ='https://github.com/new'
cookies = {'user_session':'Hl24-ZLdD0FPRVmBft2tsHfdJbOekVJgQq4bdOfX_XB3BY-E'}
res = requests.get(url,cookies = cookies)

soup = BeautifulSoup(res.text,'html.parser')
soup
#登入後發現(檢查→application中多了一個uesr_session)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-8c550109d58e0353afdf1a37a05301c2.css" integrity="sha512-jFUBCdWOA1Ov3xo3oFMBwsdP4Up2K1bRnP4QYI5WqvpaIYxWVek89k2M0oyTbNhYMViGtxJB3Vdwcw8ln8hGQw==" media="all" rel="stylesheet">
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/github-36f60e1fc11f3e85242ffa676dd886fe.css" integrity="sha512-NvYOH8EfPoUkL/pnbdiG/jpmBFbDYLFq3u7YDcnIoDy8RFMMCj2yxgbWKqSBWRpok0zDEdSYxnLQ0utEcw3BrA==" media="all" rel="stylesheet">
# <meta content="width=device-width" name="viewport"/>
# <title>Create a New Repository</title>
# <meta content="GitHub is where people build software. More than 50 million people use GitHub to discover, fork, and contribute to over 100 million projects." name="description"/>
# <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
# <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
# <meta content="1401488693436528" property="fb:app_id"/>
# <meta content="app-id=1477376905" name="apple-itunes-app"/>
# <meta content="https://github.com" property="og:url"/>
# <meta content="GitHub" property="og:site_name"/>
# <meta content="Build software better, together" property="og:title"/>
# <meta content="GitHub is where people build software. More than 50 million people use GitHub to discover, fork, and contribute to over 100 million projects." property="og:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="1200" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-mark.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-octocat.png" property="og:image"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="620" property="og:image:height"/>
# <meta content="github" property="twitter:site"/>
# <meta content="13334762" property="twitter:site:id"/>
# <meta content="github" property="twitter:creator"/>
# <meta content="13334762" property="twitter:creator:id"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="GitHub" property="twitter:title"/>
# <meta content="GitHub is where people build software. More than 50 million people use GitHub to discover, fork, and contribute to over 100 million projects." property="twitter:description"/>
# <meta content="https://github.githubassets.com/images/modules/open_graph/github-logo.png" property="twitter:image:src"/>
# <meta content="1200" property="twitter:image:width"/>
# <meta content="1200" property="twitter:image:height"/>
# <link href="https://github.githubassets.com/" rel="assets"/>
# <link data-refresh-url="/_ws" href="wss://alive.github.com/_sockets/u/66210904/ws?session=eyJ2IjoiVjMiLCJ1Ijo2NjIxMDkwNCwicyI6NTcyNTE1ODcyLCJjIjoyMzY1MTE2OTQwLCJ0IjoxNTk4MDMyMjY1fQ==--0ce500f82f98d543740648bcd158ecbf4ffcee95ff6c1cdf0da8405b14a40207" rel="shared-web-socket"/>
# <link href="/sessions/sudo_modal" rel="sudo-modal"/>
# <meta content="D79E:1A08:3F98:87DF:5F400988" data-pjax-transient="true" name="request-id"><meta content="85f0fc5856df96ab133a6a847b8e208057a331b8" data-pjax-transient="true" name="html-safe-nonce"><meta content="eyJyZWZlcnJlciI6bnVsbCwicmVxdWVzdF9pZCI6IkQ3OUU6MUEwODozRjk4Ojg3REY6NUY0MDA5ODgiLCJ2aXNpdG9yX2lkIjoiODMzNTQxNzU3MTgyNjIwNzExMyIsInJlZ2lvbl9lZGdlIjoiaWFkIiwicmVnaW9uX3JlbmRlciI6ImlhZCJ9" data-pjax-transient="true" name="visitor-payload"><meta content="70a27b574a93137e49e835ddad297fc23250eda40a92c19a9cba8bd110611d00" data-pjax-transient="true" name="visitor-hmac">
# <meta content="" data-pjax-transient="true" name="github-keyboard-shortcuts">
# <meta data-pjax-transient="" name="selected-link" value="repo_create"/>
# <meta content="c1kuD-K2HIVF635lypcsWPoD4kilo5-jA_wBFyT4uMY" name="google-site-verification"/>
# <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification"/>
# <meta content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA" name="google-site-verification"/>
# <meta content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc" name="google-site-verification"/>
# <meta content="collector.githubapp.com" name="octolytics-host"><meta content="github" name="octolytics-app-id"><meta content="https://collector.githubapp.com/github-external/browser_event" name="octolytics-event-url"><meta class="js-octo-ga-id" content="" name="octolytics-dimension-ga_id"><meta content="66210904" name="octolytics-actor-id"><meta content="skuld1020" name="octolytics-actor-login"><meta content="1f9dcc8a249a1f7b22fd6406b8b87b608bdcce17064d49fd60473f3190c14d8e" name="octolytics-actor-hash">
# <meta content="UA-3769691-2" name="google-analytics"/>
# <meta class="js-ga-set" content="1fd06c3481573c744e9fce9f3faa24c9" name="userId"/>
# <meta class="js-ga-set" content="Responsive" data-pjax-transient="" name="dimension10"/>
# <meta class="js-ga-set" content="Logged In" name="dimension1"/>
# <meta content="github.com" name="hostname"/>
# <meta content="skuld1020" name="user-login"/>
# <meta content="github.com" name="expected-hostname"/>
# <meta content="OTE5NDE2NDhiNmY3MWZhZWRiMGRiZDUyZDA1ODczYzAyZDk5M2IzZmU2ZTRkY2NlOWM4YjIwODVmYWY3NmQ5MXx7InJlbW90ZV9hZGRyZXNzIjoiMzYuMjI1LjEuMTAzIiwicmVxdWVzdF9pZCI6IkQ3OUU6MUEwODozRjk4Ojg3REY6NUY0MDA5ODgiLCJ0aW1lc3RhbXAiOjE1OTgwMzIyNjUsImhvc3QiOiJnaXRodWIuY29tIn0=" name="js-proxy-site-detection-payload"/>
# <meta content="MARKETPLACE_PENDING_INSTALLATIONS" name="enabled-features"/>
# <meta content="269f8c88eed84e4178a5f9feca9bdb9c" http-equiv="x-pjax-version"/>
# <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
# <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
# <link color="#000000" href="https://github.githubassets.com/pinned-octocat.svg" rel="mask-icon"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.png" rel="alternate icon" type="image/png"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="#1e2327" name="theme-color"/>
# <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
# </meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></meta></link></link></head>
# <body class="logged-in env-production page-responsive page-new-repo">
# <input class="js-data-websocket-refresh-csrf" data-csrf="true" type="hidden" value="xj2VEcZ0RL4lQ63j1dqhnUid82zqIxHazaHQToRfectl7PO7UwfPad3uFXKlz26tItlNvTcAnbuTeZCy9Hvjjg=="/>
# <div class="position-relative js-header-wrapper">
# <a class="p-3 bg-blue text-white show-on-focus js-skip-to-content" href="#start-of-content">Skip to content</a>
# <span class="progress-pjax-loader width-full js-pjax-loader-bar Progress position-fixed">
# <span class="Progress-item progress-pjax-loader-bar" style="background-color: #79b8ff;width: 0%;"></span>
# </span>
# <header class="Header py-md-0 js-details-container Details flex-wrap flex-md-nowrap px-3" role="banner">
# <div class="Header-item d-none d-md-flex">
# <a aria-label="Homepage " class="Header-link" data-ga-click="Header, go to dashboard, icon:logo" data-hotkey="g d" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github v-align-middle" height="32" version="1.1" viewbox="0 0 16 16" width="32"><path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path></svg>
# </a>
# </div>
# <div class="Header-item d-md-none">
# <button aria-expanded="false" aria-label="Toggle navigation" class="Header-link btn-link js-details-target" type="button">
# <svg aria-hidden="true" class="octicon octicon-three-bars" height="24" version="1.1" viewbox="0 0 16 16" width="24"><path d="M1 2.75A.75.75 0 011.75 2h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 2.75zm0 5A.75.75 0 011.75 7h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 7.75zM1.75 12a.75.75 0 100 1.5h12.5a.75.75 0 100-1.5H1.75z" fill-rule="evenodd"></path></svg>
# </button>
# </div>
# <div class="Header-item Header-item--full flex-column flex-md-row width-full flex-order-2 flex-md-order-none mr-0 mr-md-3 mt-3 mt-md-0 Details-content--hidden-not-important d-md-flex">
# <div aria-expanded="false" aria-haspopup="listbox" aria-label="Search or jump to" aria-owns="jump-to-results" class="header-search header-search-current js-header-search-current flex-auto flex-self-stretch flex-md-self-auto mr-0 mr-md-3 mb-3 mb-md-0 js-site-search position-relative js-jump-to js-header-search-current-jump-to" role="combobox">
# <div class="position-relative">
# <!-- '"` --><!-- </textarea></xmp> --></div></div></div></header></div></body></html><form accept-charset="UTF-8" action="/search" aria-label="Site" class="js-site-search-form" data-unscoped-search-url="/search" method="get" role="search">
# <label class="form-control input-sm header-search-wrapper p-0 header-search-wrapper-jump-to position-relative d-flex flex-justify-between flex-items-center js-chromeless-input-container">
# <input aria-autocomplete="list" aria-controls="jump-to-results" aria-label="Search or jump to…" autocapitalize="off" autocomplete="off" class="form-control input-sm header-search-input jump-to-field js-jump-to-field js-site-search-focus" data-hotkey="s,/" data-jump-to-suggestions-path="/_graphql/GetSuggestedNavigationDestinations" data-scoped-placeholder="Search or jump to…" data-unscoped-placeholder="Search or jump to…" name="q" placeholder="Search or jump to…" spellcheck="false" type="text" value=""/>
# <input class="js-data-jump-to-suggestions-path-csrf" data-csrf="true" type="hidden" value="rBVo2DJPr6vtzhN7j+t7/1VCCaOMofgp+4rBAo/HJFnqwi7A7ZTxChVhHeKun12VgVNPSESDsTRYGdLlPLPe2Q==">
# <input class="js-site-search-type-field" name="type" type="hidden"/>
# <img alt="" class="mr-2 header-search-key-slash" src="https://github.githubassets.com/images/search-key-slash.svg"/>
# <div class="Box position-absolute overflow-hidden d-none jump-to-suggestions js-jump-to-suggestions-container">
# <ul class="d-none js-jump-to-suggestions-template-container">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-suggestion" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16"><path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16"><path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16"><path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path></svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# </ul>
# <ul class="d-none js-jump-to-no-results-template-container">
# <li class="d-flex flex-justify-center flex-items-center f5 d-none js-jump-to-suggestion p-2">
# <span class="text-gray">No suggested jump to results</span>
# </li>
# </ul>
# <ul class="p-0 m-0 js-navigation-container jump-to-suggestions-results-container js-jump-to-suggestions-results-container" id="jump-to-results" role="listbox">
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-scoped-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16"><path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16"><path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16"><path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path></svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-start flex-items-center p-0 f5 navigation-item js-navigation-item js-jump-to-global-search d-none" role="option">
# <a class="no-underline d-flex flex-auto flex-items-center jump-to-suggestions-path js-jump-to-suggestion-path js-navigation-open p-2" href="" tabindex="-1">
# <div class="jump-to-octicon js-jump-to-octicon flex-shrink-0 mr-2 text-center d-none">
# <svg aria-label="Repository" class="octicon octicon-repo flex-shrink-0 js-jump-to-octicon-repo d-none" height="16" role="img" title="Repository" version="1.1" viewbox="0 0 16 16" width="16"><path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Project" class="octicon octicon-project flex-shrink-0 js-jump-to-octicon-project d-none" height="16" role="img" title="Project" version="1.1" viewbox="0 0 16 16" width="16"><path d="M1.75 0A1.75 1.75 0 000 1.75v12.5C0 15.216.784 16 1.75 16h12.5A1.75 1.75 0 0016 14.25V1.75A1.75 1.75 0 0014.25 0H1.75zM1.5 1.75a.25.25 0 01.25-.25h12.5a.25.25 0 01.25.25v12.5a.25.25 0 01-.25.25H1.75a.25.25 0 01-.25-.25V1.75zM11.75 3a.75.75 0 00-.75.75v7.5a.75.75 0 001.5 0v-7.5a.75.75 0 00-.75-.75zm-8.25.75a.75.75 0 011.5 0v5.5a.75.75 0 01-1.5 0v-5.5zM8 3a.75.75 0 00-.75.75v3.5a.75.75 0 001.5 0v-3.5A.75.75 0 008 3z" fill-rule="evenodd"></path></svg>
# <svg aria-label="Search" class="octicon octicon-search flex-shrink-0 js-jump-to-octicon-search d-none" height="16" role="img" title="Search" version="1.1" viewbox="0 0 16 16" width="16"><path d="M11.5 7a4.499 4.499 0 11-8.998 0A4.499 4.499 0 0111.5 7zm-.82 4.74a6 6 0 111.06-1.06l3.04 3.04a.75.75 0 11-1.06 1.06l-3.04-3.04z" fill-rule="evenodd"></path></svg>
# </div>
# <img alt="" aria-label="Team" class="avatar mr-2 flex-shrink-0 js-jump-to-suggestion-avatar d-none" height="28" src="" width="28"/>
# <div class="jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target">
# </div>
# <div class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none js-jump-to-badge-search">
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-default d-none">
#         Search
#       </span>
# <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#         All GitHub
#       </span>
# <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# <div aria-hidden="true" class="border rounded-1 flex-shrink-0 bg-gray px-1 text-gray-light ml-1 f6 d-none d-on-nav-focus js-jump-to-badge-jump">
#       Jump to
#       <span class="d-inline-block ml-1 v-align-middle">↵</span>
# </div>
# </a>
# </li>
# <li class="d-flex flex-justify-center flex-items-center p-0 f5 js-jump-to-suggestion">
# <img alt="Octocat Spinner Icon" class="m-2" src="https://github.githubassets.com/images/spinners/octocat-spinner-128.gif" width="28"/>
# </li>
# </ul>
# </div>
# </input></label>
# </form>
#
# <nav aria-label="Global" class="d-flex flex-column flex-md-row flex-self-stretch flex-md-self-auto">
# <a aria-label="Dashboard" class="Header-link py-md-3 d-block d-md-none py-2 border-top border-md-top-0 border-white-fade-15" data-ga-click="Header, click, Nav menu - item:dashboard:user" href="/dashboard">
#       Dashboard
# </a>
# <a aria-label="Pull requests you created" class="js-selected-navigation-item Header-link py-md-3 mr-0 mr-md-3 py-2 border-top border-md-top-0 border-white-fade-15" data-ga-click="Header, click, Nav menu - item:pulls context:user" data-hotkey="g p" data-selected-links="/pulls /pulls/assigned /pulls/mentioned /pulls" href="/pulls">
#       Pull<span class="d-inline d-md-none d-lg-inline"> request</span>s
# </a>
# <a aria-label="Issues you created" class="js-selected-navigation-item Header-link py-md-3 mr-0 mr-md-3 py-2 border-top border-md-top-0 border-white-fade-15" data-ga-click="Header, click, Nav menu - item:issues context:user" data-hotkey="g i" data-selected-links="/issues /issues/assigned /issues/mentioned /issues" href="/issues">
#     Issues
# </a>
# <div class="mr-0 mr-md-3 py-2 py-md-0 border-top border-md-top-0 border-white-fade-15">
# <a class="js-selected-navigation-item Header-link py-md-3 d-inline-block" data-ga-click="Header, click, Nav menu - item:marketplace context:user" data-octo-click="marketplace_click" data-octo-dimensions="location:nav_bar" data-selected-links=" /marketplace" href="/marketplace">
#         Marketplace
# </a>
# </div>
# <a class="js-selected-navigation-item Header-link py-md-3 mr-0 mr-md-3 py-2 border-top border-md-top-0 border-white-fade-15" data-ga-click="Header, click, Nav menu - item:explore" data-selected-links="/explore /trending /trending/developers /integrations /integrations/feature/code /integrations/feature/collaborate /integrations/feature/ship showcases showcases_search showcases_landing /explore" href="/explore">
#     Explore
# </a>
# <a class="Header-link d-block d-md-none mr-0 mr-md-3 py-2 py-md-3 border-top border-md-top-0 border-white-fade-15" href="/skuld1020">
# <img alt="@skuld1020" class="avatar avatar-user" height="20" src="https://avatars1.githubusercontent.com/u/66210904?s=40&amp;v=4" width="20">
#       skuld1020
# </img></a>
# <!-- '"` --><!-- </textarea></xmp> --></nav><form accept-charset="UTF-8" action="/logout" method="post"><input name="authenticity_token" type="hidden" value="eC0FocFTO0dykF7HzlKi9syDu21Pj/odiFa0KMwbmxk681mqvoH1A/vXiwwy9I01c56E3IHYNJcL7HPo1Yoegw==">
# <button class="Header-link mr-0 mr-md-3 py-2 py-md-3 border-top border-md-top-0 border-white-fade-15 d-md-none btn-link d-block width-full text-left" data-ga-click="Header, sign out, icon:logout" style="padding-left: 2px;" type="submit">
# <svg aria-hidden="true" class="octicon octicon-sign-out v-align-middle" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M2 2.75C2 1.784 2.784 1 3.75 1h2.5a.75.75 0 010 1.5h-2.5a.25.25 0 00-.25.25v10.5c0 .138.112.25.25.25h2.5a.75.75 0 010 1.5h-2.5A1.75 1.75 0 012 13.25V2.75zm10.44 4.5H6.75a.75.75 0 000 1.5h5.69l-1.97 1.97a.75.75 0 101.06 1.06l3.25-3.25a.75.75 0 000-1.06l-3.25-3.25a.75.75 0 10-1.06 1.06l1.97 1.97z" fill-rule="evenodd"></path></svg>
#         Sign out
#       </button>
# </input></form>
#
# <div class="Header-item Header-item--full flex-justify-center d-md-none position-relative">
# <a aria-label="Homepage " class="Header-link" data-ga-click="Header, go to dashboard, icon:logo" data-hotkey="g d" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github v-align-middle" height="32" version="1.1" viewbox="0 0 16 16" width="32"><path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path></svg>
# </a>
# </div>
# <div class="Header-item mr-0 mr-md-3 flex-order-1 flex-md-order-none">
# <notification-indicator class="js-socket-channel" data-channel="eyJjIjoibm90aWZpY2F0aW9uLWNoYW5nZWQ6NjYyMTA5MDQiLCJ0IjoxNTk4MDMyMjY1fQ==--0aa00246fef1157925edf5032d972d8b62f6a50a3feab68c7b914453ce5d0685">
# <a aria-label="You have no unread notifications" class="Header-link notification-indicator position-relative tooltipped tooltipped-sw" data-ga-click="Header, go to notifications, icon:read" data-hotkey="g n" data-target="notification-indicator.link" href="/notifications">
# <span class="mail-status" data-target="notification-indicator.modifier"></span>
# <svg aria-hidden="true" class="octicon octicon-bell" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 16a2 2 0 001.985-1.75c.017-.137-.097-.25-.235-.25h-3.5c-.138 0-.252.113-.235.25A2 2 0 008 16z"></path><path d="M8 1.5A3.5 3.5 0 004.5 5v2.947c0 .346-.102.683-.294.97l-1.703 2.556a.018.018 0 00-.003.01l.001.006c0 .002.002.004.004.006a.017.017 0 00.006.004l.007.001h10.964l.007-.001a.016.016 0 00.006-.004.016.016 0 00.004-.006l.001-.007a.017.017 0 00-.003-.01l-1.703-2.554a1.75 1.75 0 01-.294-.97V5A3.5 3.5 0 008 1.5zM3 5a5 5 0 0110 0v2.947c0 .05.015.098.042.139l1.703 2.555A1.518 1.518 0 0113.482 13H2.518a1.518 1.518 0 01-1.263-2.36l1.703-2.554A.25.25 0 003 7.947V5z" fill-rule="evenodd"></path></svg>
# </a>
# </notification-indicator>
# </div>
# <div class="Header-item position-relative d-none d-md-flex">
# <details class="details-overlay details-reset">
# <summary aria-label="Create new…" class="Header-link" data-ga-click="Header, create new, icon:add">
# <svg aria-hidden="true" class="octicon octicon-plus" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 2a.75.75 0 01.75.75v4.5h4.5a.75.75 0 010 1.5h-4.5v4.5a.75.75 0 01-1.5 0v-4.5h-4.5a.75.75 0 010-1.5h4.5v-4.5A.75.75 0 018 2z" fill-rule="evenodd"></path></svg> <span class="dropdown-caret"></span>
# </summary>
# <details-menu class="dropdown-menu dropdown-menu-sw mt-n2">
# <a class="dropdown-item" data-ga-click="Header, create new repository" href="/new" role="menuitem">
#   New repository
# </a>
# <a class="dropdown-item" data-ga-click="Header, import a repository" href="/new/import" role="menuitem">
#     Import repository
#   </a>
# <a class="dropdown-item" data-ga-click="Header, create new gist" href="https://gist.github.com/" role="menuitem">
#   New gist
# </a>
# <a class="dropdown-item" data-ga-click="Header, create new organization" href="/organizations/new" role="menuitem">
#     New organization
#   </a>
# <a class="dropdown-item" data-ga-click="Header, create new project" href="/new/project" role="menuitem">
#     New project
#   </a>
# </details-menu>
# </details>
# </div>
# <div class="Header-item position-relative mr-0 d-none d-md-flex">
# <details class="details-overlay details-reset js-feature-preview-indicator-container" data-feature-preview-indicator-src="/users/skuld1020/feature_preview/indicator_check">
# <summary aria-label="View profile and more" class="Header-link" data-ga-click="Header, show menu, icon:avatar">
# <img alt="@skuld1020" class="avatar avatar-user" height="20" src="https://avatars2.githubusercontent.com/u/66210904?s=60&amp;v=4" width="20">
# <span class="feature-preview-indicator js-feature-preview-indicator" hidden="" style="top: 10px;"></span>
# <span class="dropdown-caret"></span>
# </img></summary>
# <details-menu class="dropdown-menu dropdown-menu-sw mt-n2" style="width: 180px">
# <div class="header-nav-current-user css-truncate"><a class="no-underline user-profile-link px-3 pt-2 pb-2 mb-n2 mt-n1 d-block" data-ga-click="Header, go to profile, text:Signed in as" href="/skuld1020" role="menuitem">Signed in as <strong class="css-truncate-target">skuld1020</strong></a></div>
# <div class="dropdown-divider" role="none"></div>
# <div class="pl-3 pr-3 f6 user-status-container js-user-status-context lh-condensed" data-url="/users/status?compact=1&amp;link_mentions=0&amp;truncate=1">
# <div class="js-user-status-container rounded-1 px-2 py-1 mt-2 border" data-team-hovercards-enabled="">
# <details class="js-user-status-details details-reset details-overlay details-overlay-dark">
# <summary class="btn-link btn-block link-gray no-underline js-toggle-user-status-edit toggle-user-status-edit" role="menuitem">
# <div class="d-flex flex-items-center flex-items-stretch">
# <div class="f6 lh-condensed user-status-header d-flex user-status-emoji-only-header circle">
# <div class="user-status-emoji-container flex-shrink-0 mr-2 d-flex flex-items-center flex-justify-center lh-condensed-ultra v-align-bottom">
# <svg aria-hidden="true" class="octicon octicon-smiley" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0zM8 0a8 8 0 100 16A8 8 0 008 0zM5 8a1 1 0 100-2 1 1 0 000 2zm7-1a1 1 0 11-2 0 1 1 0 012 0zM5.32 9.636a.75.75 0 011.038.175l.007.009c.103.118.22.222.35.31.264.178.683.37 1.285.37.602 0 1.02-.192 1.285-.371.13-.088.247-.192.35-.31l.007-.008a.75.75 0 111.222.87l-.614-.431c.614.43.614.431.613.431v.001l-.001.002-.002.003-.005.007-.014.019a1.984 1.984 0 01-.184.213c-.16.166-.338.316-.53.445-.63.418-1.37.638-2.127.629-.946 0-1.652-.308-2.126-.63a3.32 3.32 0 01-.715-.657l-.014-.02-.005-.006-.002-.003v-.002h-.001l.613-.432-.614.43a.75.75 0 01.183-1.044h.001z" fill-rule="evenodd"></path></svg>
# </div>
# </div>
# <div class="user-status-message-wrapper f6 min-width-0" style="line-height: 20px;">
# <div class="css-truncate css-truncate-target width-fit text-gray-dark text-left">
# <span class="text-gray">Set status</span>
# </div>
# </div>
# </div>
# </summary>
# <details-dialog class="details-dialog rounded-1 anim-fade-in fast Box Box--overlay" role="dialog" tabindex="-1">
# <!-- '"` --><!-- </textarea></xmp> --></details-dialog></details></div></div></details-menu></details></div><form accept-charset="UTF-8" action="/users/status?circle=0&amp;compact=1&amp;link_mentions=0&amp;truncate=1" class="position-relative flex-auto js-user-status-form" method="post"><input name="_method" type="hidden" value="put"/><input name="authenticity_token" type="hidden" value="7VpjttY5MJLculM8r+0QHJKsz+X9GXheBYdovkY9tw9mdOIMt8NrfLvkMDOsUAObeNk/5JPQZW/QiccneeRiGw=="/>
# <div class="Box-header bg-gray border-bottom p-3">
# <button aria-label="Close dialog" class="Box-btn-octicon js-toggle-user-status-edit btn-octicon float-right" data-close-dialog="" type="reset">
# <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path></svg>
# </button>
# <h3 class="Box-title f5 text-bold text-gray-dark">Edit status</h3>
# </div>
# <input class="js-user-status-emoji-field" name="emoji" type="hidden" value=""/>
# <input class="js-user-status-org-id-field" name="organization_id" type="hidden" value=""/>
# <div class="px-3 py-2 text-gray-dark">
# <div class="js-characters-remaining-container position-relative mt-2">
# <div class="input-group d-table form-group my-0 js-user-status-form-group">
# <span class="input-group-button d-table-cell v-align-middle" style="width: 1%">
# <button aria-label="Choose an emoji" class="btn-outline btn js-toggle-user-status-emoji-picker btn-open-emoji-picker p-0" type="button">
# <span class="js-user-status-original-emoji" hidden=""></span>
# <span class="js-user-status-custom-emoji"></span>
# <span class="js-user-status-no-emoji-icon">
# <svg aria-hidden="true" class="octicon octicon-smiley" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M1.5 8a6.5 6.5 0 1113 0 6.5 6.5 0 01-13 0zM8 0a8 8 0 100 16A8 8 0 008 0zM5 8a1 1 0 100-2 1 1 0 000 2zm7-1a1 1 0 11-2 0 1 1 0 012 0zM5.32 9.636a.75.75 0 011.038.175l.007.009c.103.118.22.222.35.31.264.178.683.37 1.285.37.602 0 1.02-.192 1.285-.371.13-.088.247-.192.35-.31l.007-.008a.75.75 0 111.222.87l-.614-.431c.614.43.614.431.613.431v.001l-.001.002-.002.003-.005.007-.014.019a1.984 1.984 0 01-.184.213c-.16.166-.338.316-.53.445-.63.418-1.37.638-2.127.629-.946 0-1.652-.308-2.126-.63a3.32 3.32 0 01-.715-.657l-.014-.02-.005-.006-.002-.003v-.002h-.001l.613-.432-.614.43a.75.75 0 01.183-1.044h.001z" fill-rule="evenodd"></path></svg>
# </span>
# </button>
# </span>
# <text-expander data-emoji-url="/autocomplete/emoji" data-mention-url="/autocomplete/user-suggestions" keys=": @">
# <input aria-label="What is your current status?" autocomplete="off" class="d-table-cell width-full form-control js-user-status-message-field js-characters-remaining-field" data-maxlength="80" data-no-org-url="/autocomplete/user-suggestions" data-org-url="/suggestions?mention_suggester=1" name="message" placeholder="What's happening?" type="text" value=""/>
# </text-expander>
# <div class="error">Could not update your status, please try again.</div>
# </div>
# <div class="my-1 text-small label-characters-remaining js-characters-remaining" data-suffix="remaining" hidden="" style="margin-left: 53px">
#               80 remaining
#             </div>
# </div>
# <include-fragment class="js-user-status-emoji-picker" data-url="/users/status/emoji"></include-fragment>
# <div class="overflow-auto ml-n3 mr-n3 px-3 border-bottom" style="max-height: 33vh">
# <div class="user-status-suggestions js-user-status-suggestions collapsed overflow-hidden">
# <h4 class="f6 text-normal my-3">Suggestions:</h4>
# <div class="mx-3 mt-2 clearfix">
# <div class="float-left col-6">
# <button class="d-flex flex-items-baseline flex-items-stretch lh-condensed f6 btn-link link-gray no-underline js-predefined-user-status mb-1" type="button" value=":palm_tree:">
# <div class="emoji-status-width mr-2 v-align-middle js-predefined-user-status-emoji">
# <g-emoji alias="palm_tree" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f334.png">🌴</g-emoji>
# </div>
# <div class="d-flex flex-items-center no-underline js-predefined-user-status-message ws-normal text-left" style="border-left: 1px solid transparent">
#                           On vacation
#                         </div>
# </button>
# <button class="d-flex flex-items-baseline flex-items-stretch lh-condensed f6 btn-link link-gray no-underline js-predefined-user-status mb-1" type="button" value=":face_with_thermometer:">
# <div class="emoji-status-width mr-2 v-align-middle js-predefined-user-status-emoji">
# <g-emoji alias="face_with_thermometer" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f912.png">🤒</g-emoji>
# </div>
# <div class="d-flex flex-items-center no-underline js-predefined-user-status-message ws-normal text-left" style="border-left: 1px solid transparent">
#                           Out sick
#                         </div>
# </button>
# </div>
# <div class="float-left col-6">
# <button class="d-flex flex-items-baseline flex-items-stretch lh-condensed f6 btn-link link-gray no-underline js-predefined-user-status mb-1" type="button" value=":house:">
# <div class="emoji-status-width mr-2 v-align-middle js-predefined-user-status-emoji">
# <g-emoji alias="house" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f3e0.png">🏠</g-emoji>
# </div>
# <div class="d-flex flex-items-center no-underline js-predefined-user-status-message ws-normal text-left" style="border-left: 1px solid transparent">
#                           Working from home
#                         </div>
# </button>
# <button class="d-flex flex-items-baseline flex-items-stretch lh-condensed f6 btn-link link-gray no-underline js-predefined-user-status mb-1" type="button" value=":dart:">
# <div class="emoji-status-width mr-2 v-align-middle js-predefined-user-status-emoji">
# <g-emoji alias="dart" fallback-src="https://github.githubassets.com/images/icons/emoji/unicode/1f3af.png">🎯</g-emoji>
# </div>
# <div class="d-flex flex-items-center no-underline js-predefined-user-status-message ws-normal text-left" style="border-left: 1px solid transparent">
#                           Focusing
#                         </div>
# </button>
# </div>
# </div>
# </div>
# <div class="user-status-limited-availability-container">
# <div class="form-checkbox my-0">
# <input aria-describedby="limited-availability-help-text-truncate-true-compact-true" class="js-user-status-limited-availability-checkbox" data-default-message="I may be slow to respond." id="limited-availability-truncate-true-compact-true" name="limited_availability" type="checkbox" value="1"/>
# <label class="d-block f5 text-gray-dark mb-1" for="limited-availability-truncate-true-compact-true">
#                   Busy
#                 </label>
# <p class="note" id="limited-availability-help-text-truncate-true-compact-true">
#                   When others mention you, assign you, or request your review,
#                   GitHub will let them know that you have limited availability.
#                 </p>
# </div>
# </div>
# </div>
# <div class="d-inline-block f5 mr-2 pt-3 pb-2">
# <div class="d-inline-block mr-1">
#     Clear status
#   </div>
# <details class="js-user-status-expire-drop-down f6 dropdown details-reset details-overlay d-inline-block mr-2">
# <summary aria-haspopup="true" class="btn btn-sm v-align-baseline">
# <div class="js-user-status-expiration-interval-selected d-inline-block v-align-baseline">
#         Never
#       </div>
# <div class="dropdown-caret"></div>
# </summary>
# <ul class="dropdown-menu dropdown-menu-se pl-0 overflow-auto" style="width: 220px; max-height: 15.5em">
# <li>
# <button class="btn-link dropdown-item js-user-status-expire-button ws-normal" title="Never" type="button">
# <span class="d-inline-block text-bold mb-1">Never</span>
# <div class="f6 lh-condensed">Keep this status until you clear your status or edit your status.</div>
# </button>
# </li>
# <li class="dropdown-divider" role="none"></li>
# <li>
# <button class="btn-link dropdown-item ws-normal js-user-status-expire-button" title="in 30 minutes" type="button" value="2020-08-21T18:21:05Z">
#             in 30 minutes
#           </button>
# </li>
# <li>
# <button class="btn-link dropdown-item ws-normal js-user-status-expire-button" title="in 1 hour" type="button" value="2020-08-21T18:51:05Z">
#             in 1 hour
#           </button>
# </li>
# <li>
# <button class="btn-link dropdown-item ws-normal js-user-status-expire-button" title="in 4 hours" type="button" value="2020-08-21T21:51:05Z">
#             in 4 hours
#           </button>
# </li>
# <li>
# <button class="btn-link dropdown-item ws-normal js-user-status-expire-button" title="today" type="button" value="2020-08-21T23:59:59Z">
#             today
#           </button>
# </li>
# <li>
# <button class="btn-link dropdown-item ws-normal js-user-status-expire-button" title="this week" type="button" value="2020-08-23T23:59:59Z">
#             this week
#           </button>
# </li>
# </ul>
# </details>
# <input class="js-user-status-expiration-date-input" name="expires_at" type="hidden" value=""/>
# </div>
# <include-fragment class="js-user-status-org-picker" data-url="/users/status/organizations"></include-fragment>
# </div>
# <div class="d-flex flex-items-center flex-justify-between p-3 border-top">
# <button class="width-full btn btn-primary mr-2 js-user-status-submit" disabled="" type="submit">
#             Set status
#           </button>
# <button class="width-full js-clear-user-status-button btn ml-2" disabled="" type="button">
#             Clear status
#           </button>
# </div>
# </form>
#
#
#
# <div class="dropdown-divider" role="none"></div>
# <a class="dropdown-item" data-ga-click="Header, go to profile, text:your profile" data-hydro-click='{"event_type":"global_header.user_menu_dropdown.click","payload":{"request_url":"https://github.com/new","target":"YOUR_PROFILE","originating_url":"https://github.com/new","user_id":66210904}}' data-hydro-click-hmac="02c4ca27a9fb2d183dbed7e6ee856d70b74a9942b7b5cc0052d48bb7fad2c68c" href="/skuld1020" role="menuitem">Your profile</a>
# <a class="dropdown-item" data-ga-click="Header, go to repositories, text:your repositories" data-hydro-click='{"event_type":"global_header.user_menu_dropdown.click","payload":{"request_url":"https://github.com/new","target":"YOUR_REPOSITORIES","originating_url":"https://github.com/new","user_id":66210904}}' data-hydro-click-hmac="585178dded1383745807cf6ce95206f02b0e452e05e5f83480884bbdeca75573" href="/skuld1020?tab=repositories" role="menuitem">Your repositories</a>
# <a class="dropdown-item" data-ga-click="Header, go to projects, text:your projects" data-hydro-click='{"event_type":"global_header.user_menu_dropdown.click","payload":{"request_url":"https://github.com/new","target":"YOUR_PROJECTS","originating_url":"https://github.com/new","user_id":66210904}}' data-hydro-click-hmac="f2f3f661c6c34023baa330b915274fe402e02f09a736365d02618d8a98ae52f6" href="/skuld1020?tab=projects" role="menuitem">Your projects</a>
# <a class="dropdown-item" data-ga-click="Header, go to starred repos, text:your stars" data-hydro-click='{"event_type":"global_header.user_menu_dropdown.click","payload":{"request_url":"https://github.com/new","target":"YOUR_STARS","originating_url":"https://github.com/new","user_id":66210904}}' data-hydro-click-hmac="b34692f32ef983c96f0e2e61f1cb1012d0d832856153262c36090e88d8097399" href="/skuld1020?tab=stars" role="menuitem">Your stars</a>
# <a class="dropdown-item" data-ga-click="Header, your gists, text:your gists" data-hydro-click='{"event_type":"global_header.user_menu_dropdown.click","payload":{"request_url":"https://github.com/new","target":"YOUR_GISTS","originating_url":"https://github.com/new","user_id":66210904}}' data-hydro-click-hmac="c2674fadfa77058d392f257adb5fb8f936ad19a2718377e7549dd34ce1c904da" href="https://gist.github.com/mine" role="menuitem">Your gists</a>
# <div class="dropdown-divider" role="none"></div>
# <a class="dropdown-item" data-ga-click="Header, go to billing, text:upgrade" data-hydro-click='{"event_type":"global_header.user_menu_dropdown.click","payload":{"request_url":"https://github.com/new","target":"UPGRADE","originating_url":"https://github.com/new","user_id":66210904}}' data-hydro-click-hmac="1eaebcc90f4ab9b0e05bab6fbaa1723962c7c485125558f760a156ba65fa8ce8" href="/settings/billing" role="menuitem">Upgrade</a>
# <div class="hide-sm hide-md feature-preview-details position-relative" id="feature-enrollment-toggle">
# <button class="dropdown-item btn-link" data-feature-preview-close-details='{"event_type":"feature_preview.clicks.close_modal","payload":{"originating_url":"https://github.com/new","user_id":66210904}}' data-feature-preview-close-hmac="54ea78517263247686015635bd3e808e8d8d6cebf58ce0310c67580acf16d387" data-feature-preview-trigger-url="/users/skuld1020/feature_previews" data-hydro-click='{"event_type":"feature_preview.clicks.open_modal","payload":{"link_location":"user_dropdown","originating_url":"https://github.com/new","user_id":66210904}}' data-hydro-click-hmac="6c046f8a41d4984909d12879245dc236a7c028456c7d6973373cf6e036c72b7f" role="menuitem" type="button">
#     Feature preview
#   </button>
# <span class="feature-preview-indicator js-feature-preview-indicator" hidden=""></span>
# </div>
# <a class="dropdown-item" data-ga-click="Header, go to help, text:help" data-hydro-click='{"event_type":"global_header.user_menu_dropdown.click","payload":{"request_url":"https://github.com/new","target":"HELP","originating_url":"https://github.com/new","user_id":66210904}}' data-hydro-click-hmac="df1966ad035f459c55eaa6301a196b189944ceacac68573e3d7d11422ab319a5" href="https://docs.github.com" role="menuitem">Help</a>
# <a class="dropdown-item" data-ga-click="Header, go to settings, icon:settings" data-hydro-click='{"event_type":"global_header.user_menu_dropdown.click","payload":{"request_url":"https://github.com/new","target":"SETTINGS","originating_url":"https://github.com/new","user_id":66210904}}' data-hydro-click-hmac="fd35cf090ecdbb3c76379b241b07dc507036560e1248cb4efec1216cc827a1d2" href="/settings/profile" role="menuitem">Settings</a>
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="/logout" class="logout-form" method="post"><input name="authenticity_token" type="hidden" value="tNCMKb8CSgk5fY0v7q1PWuy+F4b2/Nf4Tx+ZbynvwMn2DtAiwNCETbA6WOQSC2CZU6MoNzirGXLMpV6vMH5FUw==">
# <button class="dropdown-item dropdown-signout" data-ga-click="Header, sign out, icon:logout" data-hydro-click='{"event_type":"global_header.user_menu_dropdown.click","payload":{"request_url":"https://github.com/new","target":"SIGN_OUT","originating_url":"https://github.com/new","user_id":66210904}}' data-hydro-click-hmac="221345642696140664ada82c220e374b932f6715c3fc59a97bb290bafd271d3b" role="menuitem" type="submit">
#         Sign out
#       </button>
# <input class="form-control" hidden="hidden" name="required_field_9e11" type="text"><input class="form-control" name="timestamp" type="hidden" value="1598032265546"><input class="form-control" name="timestamp_secret" type="hidden" value="5b11106a303eeb5eea7330e0882d9067eb8bd97616e865b8751ae6039577223f">
# </input></input></input></input></form>
#
#
#
#
# <div class="show-on-focus" id="start-of-content"></div>
# <div id="js-flash-container">
# <template class="js-flash-template">
# <div class="flash flash-full {{ className }}">
# <div class="container-lg px-2">
# <button aria-label="Dismiss this message" class="flash-close js-flash-close" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path></svg>
# </button>
# <div>{{ message }}</div>
# </div>
# </div>
# </template>
# </div>
# <include-fragment class="js-notification-shelf-include-fragment" data-base-src="https://github.com/notifications/beta/shelf"></include-fragment>
# <div class="application-main" data-commit-hovercards-enabled="" data-discussion-hovercards-enabled="" data-issue-and-pr-hovercards-enabled="">
# <main data-pjax-container="" id="js-pjax-container">
# <div class="container-md my-6 px-3 px-md-4 px-lg-5">
# <!-- '"` --><!-- </textarea></xmp> --></div></main></div><form accept-charset="UTF-8" action="/repositories" aria-label="Create a new repository" class="js-braintree-encrypt js-repo-form" data-braintree-key="" id="new_repository" method="post"><input name="authenticity_token" type="hidden" value="R+YVJZ5c+7EJmZiM0ZCzuw7jifVObHKKjQukL+buxKih0D3pvLb2/xzH4P+n/jxkhMoeQU+z7prm9wM3WVeuQw==">
# <div class="Subhead hx_Subhead--responsive mb-5">
# <h1 class="Subhead-heading">
#       Create a new repository
# </h1> <div class="Subhead-description">
# ...
# </label>
# <label aria-checked="false" class="SelectMenu-item text-normal" role="menuitemradio" tabindex="0">
# <input autocomplete="off" class="" hidden="" name="repository[license_template]" type="radio" value="agpl-3.0"/>
# <svg aria-hidden="true" class="octicon octicon-check SelectMenu-icon SelectMenu-icon--check" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path></svg>
# <div>
# <div class="">
#       GNU Affero General Public License v3.0
#     </div>
# </div>
# <span data-filter-item-text="" data-menu-button-text="" hidden="">
#       GNU Affero General Public License v3.0
#     </span>
# </label>
# <label aria-checked="false" class="SelectMenu-item text-normal" role="menuitemradio" tabindex="0">
# <input autocomplete="off" class="" hidden="" name="repository[license_template]" type="radio" value="gpl-2.0"/>
# <svg aria-hidden="true" class="octicon octicon-check SelectMenu-icon SelectMenu-icon--check" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path></svg>
# <div>
# <div class="">
#       GNU General Public License v2.0
#     </div>
# </div>
# <span data-filter-item-text="" data-menu-button-text="" hidden="">
#       GNU General Public License v2.0
#     </span>
# </label>
# <label aria-checked="false" class="SelectMenu-item text-normal" role="menuitemradio" tabindex="0">
# <input autocomplete="off" class="" hidden="" name="repository[license_template]" type="radio" value="lgpl-2.1"/>
# <svg aria-hidden="true" class="octicon octicon-check SelectMenu-icon SelectMenu-icon--check" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path></svg>
# <div>
# <div class="">
#       GNU Lesser General Public License v2.1
#     </div>
# </div>
# <span data-filter-item-text="" data-menu-button-text="" hidden="">
#       GNU Lesser General Public License v2.1
#     </span>
# </label>
# <label aria-checked="false" class="SelectMenu-item text-normal" role="menuitemradio" tabindex="0">
# <input autocomplete="off" class="" hidden="" name="repository[license_template]" type="radio" value="mpl-2.0"/>
# <svg aria-hidden="true" class="octicon octicon-check SelectMenu-icon SelectMenu-icon--check" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path></svg>
# <div>
# <div class="">
#       Mozilla Public License 2.0
#     </div>
# </div>
# <span data-filter-item-text="" data-menu-button-text="" hidden="">
#       Mozilla Public License 2.0
#     </span>
# </label>
# <label aria-checked="false" class="SelectMenu-item text-normal" role="menuitemradio" tabindex="0">
# <input autocomplete="off" class="" hidden="" name="repository[license_template]" type="radio" value="unlicense"/>
# <svg aria-hidden="true" class="octicon octicon-check SelectMenu-icon SelectMenu-icon--check" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path></svg>
# <div>
# <div class="">
#       The Unlicense
#     </div>
# </div>
# <span data-filter-item-text="" data-menu-button-text="" hidden="">
#       The Unlicense
#     </span>
# </label>
# <div class="SelectMenu-blankslate" data-filter-empty-state="" hidden="">
#               No results found.
#             </div>
# </div>
# </div>
# </div>
# </details-menu>
# </details>
# <a aria-label="Need help picking a license? We’ve built a site just for you." class="v-align-middle ml-2 tooltipped tooltipped-s" href="https://choosealicense.com" target="_blank">
# <svg aria-hidden="true" class="octicon octicon-info" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8 1.5a6.5 6.5 0 100 13 6.5 6.5 0 000-13zM0 8a8 8 0 1116 0A8 8 0 010 8zm6.5-.25A.75.75 0 017.25 7h1a.75.75 0 01.75.75v2.75h.25a.75.75 0 010 1.5h-2a.75.75 0 010-1.5h.25v-2h-.25a.75.75 0 01-.75-.75zM8 6a1 1 0 100-2 1 1 0 000 2z" fill-rule="evenodd"></path></svg>
# </a>
# </div>
# </div>
# </div>
# <div class="js-quick-install-container">
# <hr aria-hidden="true" class="js-quick-install-divider" hidden=""/>
# <div class="js-account-apps">
# <div data-login="skuld1020">
# </div>
# </div>
# </div>
# <hr aria-hidden="true"/>
# <button class="btn btn-primary first-in-line" data-disable-invalid="" data-disable-with="Creating repository…" type="submit">
#         Create repository
#       </button>
# </div><!-- /.js-with-permission-fields -->
# <div class="js-without-permission-fields mt-2" hidden="">
# <div class="flash flash-warn">
#         You don’t appear to have permission to create repositories for this organization. Sorry about that.
#       </div>
# </div>
# </input></form>
# <!-- '"` --><!-- </textarea></xmp> --><form accept-charset="UTF-8" action="/new" id="js-payment-methods-form" method="post" style="display:none"><input name="authenticity_token" type="hidden" value="3j2ck/dUCqlQi2fPid1x39SZavZRw4C9+qRZwUoXNeRXJ1MQ05NWqCIGd3zCtq/QApjiJpEYWziVK0kbhzhpCw=="/></form>
#
#
# <div class="footer container-lg width-full p-responsive" role="contentinfo">
# <div class="position-relative d-flex flex-row-reverse flex-lg-row flex-wrap flex-lg-nowrap flex-justify-center flex-lg-justify-between pt-6 pb-2 mt-6 f6 text-gray border-top border-gray-light">
# <ul class="list-style-none d-flex flex-wrap col-12 col-lg-5 flex-justify-center flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mr-3 mr-lg-0">© 2020 GitHub, Inc.</li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to terms, text:terms" href="https://github.com/site/terms">Terms</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to privacy, text:privacy" href="https://github.com/site/privacy">Privacy</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to security, text:security" href="https://github.com/security">Security</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to status, text:status" href="https://githubstatus.com/">Status</a></li>
# <li><a data-ga-click="Footer, go to help, text:help" href="https://docs.github.com">Help</a></li>
# </ul>
# <a aria-label="Homepage" class="footer-octicon d-none d-lg-block mx-lg-4" href="https://github.com" title="GitHub">
# <svg aria-hidden="true" class="octicon octicon-mark-github" height="24" version="1.1" viewbox="0 0 16 16" width="24"><path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path></svg>
# </a>
# <ul class="list-style-none d-flex flex-wrap col-12 col-lg-5 flex-justify-center flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to contact, text:contact" href="https://github.com/contact">Contact GitHub</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to Pricing, text:Pricing" href="https://github.com/pricing">Pricing</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to api, text:api" href="https://docs.github.com">API</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to training, text:training" href="https://services.github.com">Training</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to blog, text:blog" href="https://github.blog">Blog</a></li>
# <li><a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a></li>
# </ul>
# </div>
# <div class="d-flex flex-justify-center pb-6">
# <span class="f6 text-gray-light"></span>
# </div>
# </div>
# <div class="ajax-error-message flash flash-error" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path></svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path></svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <script async="async" crossorigin="anonymous" data-src="https://github.githubassets.com/assets/compat-bootstrap-6e7ff7ac.js" id="js-conditional-compat" integrity="sha512-bn/3rKJzBl2H64K38R8KaVcT26vKK7BJQC59lwYc+9fjlHzmy0fwh+hzBtsgTdhIi13dxjzNKWhdSN8WTM9qUw==" type="application/javascript"></script>
# <script crossorigin="anonymous" integrity="sha512-CxjaMepCmi+z0LTeztU2S8qGD25LyHD6j9t0RSPevy63trFWJVwUM6ipAVLgtpMBBgZ53wq8JPkSeQ6ruaZL2w==" src="https://github.githubassets.com/assets/environment-bootstrap-0b18da31.js" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" integrity="sha512-IzHxwH/3JQZfzvuwDWsyetKq8ns1nrrFWFyewxnSV8Vtb8hHN+l+BSPfFgYCC4eiNfzk1ZhKQl5WSv5k8dhJcg==" src="https://github.githubassets.com/assets/vendor-2331f1c0.js" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" integrity="sha512-SV6+q8uXFyBUWqEkDIVsYjJQXbWBMiPgHnfwvyqDM9HLivaP1y6WTLwXq4KhA9FMMNe0goW7KIidp3oba/Xc8Q==" src="https://github.githubassets.com/assets/frameworks-495ebeab.js" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" integrity="sha512-B3oIIhkdTIpj/Ksw5Of4I2hcifoHv8UNyFdLdVsmV55JQ2KWWlhWcenavdyhx/M5LzMXqp4jJaxiFnRUguYhmA==" src="https://github.githubassets.com/assets/behaviors-bootstrap-077a0822.js" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" data-module-id="./Sortable.js" data-src="https://github.githubassets.com/assets/Sortable-4e398351.js" integrity="sha512-TjmDUfspgN28WRWfc01tOL0BFS8pI/TAi8TQ665TcA3jG1C3QgfFu0YKa32Z03rlEL8dukbsy+amwBzgGyjESQ==" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" data-module-id="./contributions-spider-graph.js" data-src="https://github.githubassets.com/assets/contributions-spider-graph-f2149c97.js" integrity="sha512-8hScl0DkWwAjCqAQA50kQOn2QTYfPcKEyJjkKYtjGB88r9GB/6kmBBsneJPgwhW3yewwt64ABgsQGpQSLX8zpg==" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" data-module-id="./drag-drop.js" data-src="https://github.githubassets.com/assets/drag-drop-a7f9f6bb.js" integrity="sha512-p/n2uyeIUJ0ZzcJpzN2xH/pWSc/7ma1KYdOzhZf99ejmsdlsUAl0cXnptZfWJM7Vd8dhQGfhqfn4xJux5cgaVg==" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" data-module-id="./image-crop-element-loader.js" data-src="https://github.githubassets.com/assets/image-crop-element-loader-88bb82db.js" integrity="sha512-iLuC2weaJqL9mYAud2WDWjhd8cJe8dXVxw2KhCH2Rnj6WJvTzlZRmvTtL09wNWX6nRze/TDaQ7gq7BFLchaDYg==" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" data-module-id="./jump-to.js" data-src="https://github.githubassets.com/assets/jump-to-69a58607.js" integrity="sha512-aaWGB9J9tiPrApA/TphHG7EYGpV9Y81ohGUYxy8xm9PAYTFBFWtI36T8g4B8HTJCN7Azzf+WX7x3+rfYb4Nrcg==" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" data-module-id="./profile-pins-element.js" data-src="https://github.githubassets.com/assets/profile-pins-element-1f359478.js" integrity="sha512-HzWUeLy0p20M4Lc3+EerTwy/VaH3vMuKLvhFJr0PsJfKXnsD9oy5SfashhxStUirglhYZUB4fLYQRM1uzrFyNg==" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" data-module-id="./randomColor.js" data-src="https://github.githubassets.com/assets/randomColor-a840affe.js" integrity="sha512-qECv/jhsvLFN77eGNu0cjMR2+zvAlLyhQVTnmayJc5OLZoxMLjQZxZW1hK/dhcYro6Wec/aiF21HYf2N5OilYQ==" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" data-module-id="./tweetsodium.js" data-src="https://github.githubassets.com/assets/tweetsodium-987aac13.js" integrity="sha512-mHqsE5aQq7fAmmLd0epHBJK8rn8DOVnjW2YQOT8wvsN1oLrypw0cDFmwXPDwbMghHyo4kKiOtVJ/kEsEzwwibw==" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" data-module-id="./user-status-submit.js" data-src="https://github.githubassets.com/assets/user-status-submit-98d9c443.js" integrity="sha512-mNnEQyRrGnUV16QPZbBn02HR4XiKAn0sGYkalkzX4MmAmnmSrkrbIrLCX7/ry3J93s8ehsIoPn6Ua3AMorNgMA==" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" integrity="sha512-0gVVE2c8yJsGHfgcnEKR5k8kuWO8h4hdsiFV5XeN1Ay3X64gwi0DlwyVc4snK7myGn7yiUNkjWwprWuyY/ukgA==" src="https://github.githubassets.com/assets/billing-d2055513.js" type="application/javascript"></script>
# <script async="async" crossorigin="anonymous" integrity="sha512-ALIi035+4c+/6JkVB/0I7/go/s/grxrpoCCX4918OTZAh1kCqxsPzRjgcfW1H9iLs68yLAnRN3uA72yNQA0T/w==" src="https://github.githubassets.com/assets/github-bootstrap-00b222d3.js" type="application/javascript"></script>
# <div class="js-stale-session-flash flash flash-warn flash-banner" hidden="">
# <svg aria-hidden="true" class="octicon octicon-alert" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path></svg>
# <span class="js-stale-session-flash-signed-in" hidden="">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>
# <span class="js-stale-session-flash-signed-out" hidden="">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>
# </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default text-gray-dark hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path></svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box box-shadow-large" style="width:360px;">
# </div>
# </div>
